# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk, re, pprint
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))
nltk_data[:2]
# Out:
# [[('Pierre', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   (',', '.'),
#   ('61', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('join', 'VERB'),
#   ('the', 'DET'),
#   ('board', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('Nov.', 'NOUN'),
#   ('29', 'NUM'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   ('is', 'VERB'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Elsevier', 'NOUN'),
#   ('N.V.', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Dutch', 'NOUN'),
#   ('publishing', 'VERB'),
#   ('group', 'NOUN'),
#   ('.', '.')]]

# %%
# splitting data into 95:5 train-test sets
train_set, test_set = train_test_split(nltk_data,test_size=0.05, random_state=100)

# %%
# checking size of train and test set
print(len(train_set))
print(len(test_set))
# Out:
# 3718
# 196

# %%
# checking a sentence with tag
train_set[0]
# Out:
# [('One', 'NUM'),
#  ('bright', 'ADJ'),
#  ('sign', 'NOUN'),
#  ('is', 'VERB'),
#  ('that', 'ADP'),
#  ('a', 'DET'),
#  ('growing', 'VERB'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('women', 'NOUN'),
#  ('have', 'VERB'),
#  ('entered', 'VERB'),
#  ('the', 'DET'),
#  ('once', 'ADV'),
#  ('male-dominated', 'ADJ'),
#  ('field', 'NOUN'),
#  (';', '.'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('third', 'ADJ'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('ringers', 'NOUN'),
#  ('today', 'NOUN'),
#  ('are', 'VERB'),
#  ('women', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# ### Exploratory analysis on the data

# %%
# getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
train_tagged_words[:10]
# Out:
# [('One', 'NUM'),
#  ('bright', 'ADJ'),
#  ('sign', 'NOUN'),
#  ('is', 'VERB'),
#  ('that', 'ADP'),
#  ('a', 'DET'),
#  ('growing', 'VERB'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('women', 'NOUN')]

# %%
# getting tokens
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['One',
#  'bright',
#  'sign',
#  'is',
#  'that',
#  'a',
#  'growing',
#  'number',
#  'of',
#  'women']

# %%
# getting unique tokens
V = list(set(tokens))
V
# Out:
# ['victims',
#  'Peabody',
#  'oilman',
#  'installing',
#  'for',
#  'attracts',
#  'stated',
#  'comment',
#  'desultory',
#  'particulars',
#  'sentimental',
#  'exercisable',
#  'Finmeccanica',
#  'Al',
#  '450',
#  'markets',
#  'Wickliffe',
#  'thrifts',
#  '*-117',
#  'pressure',
#  'hits',
#  'Westport',
#  'tapes',
#  '280',
#  'fixtures',
#  'waited',
#  'securities-based',
#  'Among',
#  '1.49',
#  'disruptive',
#  'stick',
#  'Died',
#  'Ames',
#  'intended',
#  'leap',
#  'functions',
#  '94.2',
#  'Bougainville',
#  'concede',
#  'opening',
#  '9.3',
#  '1940s',
#  'Machines',
#  'improvement',
#  'remarks',
#  'Citing',
#  'hedging',
#  'Hong',
#  'distributes',
#  'companion',
#  'overtime',
#  'Prime',
#  'subcontractor',
#  "'S",
#  'manufacturers',
#  'Borough',
#  'brilliant',
#  'Imports',
#  'garage',
#  'Over',
#  'despise',
#  'GRAINS',
#  'Experts',
#  'thousand',
#  'mitigate',
#  'marginally',
#  'increasing',
#  'asset-valuation',
#  '77.70',
#  'copying',
#  '917',
#  'Nature',
#  'lying',
#  'foreign-stock',
#  'feeling',
#  'ready',
#  'Barnett',
#  'mechanical',
#  'top-selling',
#  'proceeds',
#  'initiative',
#  'redemption',
#  'Fischer',
#  '*-94',
#  'ministry',
#  'largely',
#  'charged',
#  'improved',
#  'belong',
#  'morass',
#  'disposed',
#  'fly',
#  '*T*-181',
#  'marriages',
#  'exposure',
#  'Publications',
#  'diminished',
#  'tenure',
#  'position',
#  'Smith',
#  '98.3',
#  'farm',
#  'steelmaker',
#  'accomplishments',
#  'necks',
#  'hauling',
#  'personally',
#  'NL',
#  '4.1',
#  'takeover-stock',
#  '*-133',
#  'equivalent',
#  'Internatonal',
#  'broken',
#  'politicians',
#  'prospectively',
#  'Mickey',
#  'Pamplin',
#  'impartial',
#  'decided',
#  'touch',
#  '13',
#  'Shearson',
#  'Last',
#  'arbitrage',
#  'employment',
#  'Image',
#  '1989-90',
#  'gentle',
#  'shallow',
#  'Kodansha',
#  'Robert',
#  'recommended',
#  '190-point',
#  'painted',
#  'waterworks',
#  'annually',
#  'SAT',
#  'bothered',
#  'debentures',
#  'matching',
#  'pasta',
#  'Story',
#  'maybe',
#  'weekly',
#  'undersecretary',
#  '811.9',
#  'classmates',
#  'Gov.',
#  'rate',
#  'banquet',
#  'weak',
#  'subjecting',
#  '1985',
#  'wears',
#  'sharply',
#  'peaked',
#  'combination',
#  'concentrate',
#  'built-from-kit',
#  'acquirer',
#  '*-162',
#  'Malcolm',
#  'stockpiles',
#  'shambles',
#  'politically',
#  'future',
#  'Eurobonds',
#  'Account',
#  'unlike',
#  'efficiencies',
#  'open-end',
#  'County',
#  'expecting',
#  'automobile',
#  'Leo',
#  'U.S.S.R.',
#  'pace',
#  'faith',
#  '*-21',
#  'Higher',
#  'B.',
#  'pact',
#  'badly',
#  'operate',
#  'belonging',
#  'Lindner',
#  'Garret',
#  'architectural',
#  'avenues',
#  'notified',
#  'error',
#  'diaper',
#  'undertone',
#  'decay',
#  'Eugene',
#  'Hearst',
#  'Seoul',
#  'millions',
#  'ascendency',
#  'charm',
#  'Wells',
#  'bombarding',
#  'maximum',
#  'certainly',
#  'Plans',
#  'property',
#  'adopt',
#  'detailed',
#  'sky',
#  'Gayle',
#  '2.07',
#  'CALL',
#  '245',
#  'Related',
#  'ballpark',
#  'debate',
#  'crisis',
#  'Fla.',
#  'bankruptcy-law',
#  'adapted',
#  'whirling',
#  'mathematical',
#  '3.625',
#  'Berlin',
#  'labeled',
#  'conglomerate',
#  'Products',
#  'sex',
#  'Lilly',
#  'sharper',
#  'midsized',
#  'dummies',
#  'entrusted',
#  'ads',
#  'N.J.',
#  'advised',
#  'resilient',
#  'Judicial',
#  'M.',
#  'plea',
#  'divergence',
#  'HHS',
#  'Dinkins',
#  'hotel',
#  'knocked',
#  '*T*-138',
#  'tentatively',
#  'provides',
#  'standards',
#  'kinds',
#  'launched',
#  'Genie',
#  'Madison',
#  'life-insurance',
#  'said',
#  'Knapp',
#  'Motor',
#  'sent',
#  'championing',
#  'DES',
#  'overstated',
#  'Stena',
#  'sticker-shock',
#  'regarded',
#  'exerting',
#  'slump',
#  'Reupke',
#  'refunds',
#  'Hills',
#  'reserve',
#  'speedway',
#  'Everybody',
#  'move',
#  'reservations',
#  'countries',
#  '99',
#  '7.45',
#  'time',
#  'Yorker',
#  'Collins',
#  'Rumors',
#  'walking',
#  'possibility',
#  'significance',
#  'played',
#  '14,821',
#  'Crum',
#  'Hart-Scott-Rodino',
#  'sympathetic',
#  'preliminary',
#  'barking',
#  'Just',
#  'Freeport-McMoRan',
#  'him',
#  'flagrant',
#  'cosmetic',
#  'stimulating',
#  'sluggishness',
#  'makers',
#  'Charities',
#  'performing',
#  '6,000',
#  'lawmakers',
#  'fabled',
#  '*T*-20',
#  'Friedrichs',
#  'intrusion',
#  'Austrian',
#  'Souper',
#  'goes',
#  'Taizo',
#  'capital',
#  '1.76',
#  'queuing',
#  'Virgin',
#  'crib',
#  'Pardus',
#  'Designated',
#  '1.916',
#  'hub',
#  'Even',
#  'failures',
#  'fluctuation',
#  'Declining',
#  '120-a-share',
#  '*T*-110',
#  'barrel',
#  'Scott',
#  'Private',
#  'bankruptcy',
#  'transplant',
#  'Engineers',
#  '19.50',
#  'net',
#  'bat',
#  '236.74',
#  'stands',
#  'witches',
#  'detail',
#  'withhold',
#  'one-month',
#  'war-damaged',
#  'Soon',
#  'cartoonist',
#  'tumbled',
#  'interpretation',
#  'cautioned',
#  'bonuses',
#  'Houston',
#  'student-test',
#  'tell',
#  'parishes',
#  'centennial',
#  'in',
#  'sticky',
#  '*T*-8',
#  'loom',
#  'skip',
#  'cases',
#  'disaffiliation',
#  '*-163',
#  '*T*-128',
#  'recovery',
#  'trends',
#  'lock',
#  'Driskill',
#  'privacy',
#  'fight',
#  'Ariail',
#  'Ten',
#  'nearly-30',
#  'Rouge',
#  'Gaja',
#  'citizen-sparked',
#  'commit',
#  'meets',
#  'A',
#  'Investments',
#  'apologizing',
#  'Germany',
#  '240',
#  'playwright',
#  'raises',
#  'complete',
#  'reds',
#  'keeping',
#  'Typical',
#  'Goodman',
#  'Williams',
#  '251.2',
#  'Nor',
#  'Nikkei',
#  'proving',
#  'fingers',
#  'Charlie',
#  'chary',
#  'behavior',
#  'CIA',
#  'wholesale',
#  'Wis.',
#  'firmed',
#  'Reliance',
#  'Russel',
#  'Both',
#  '3.2',
#  'concern',
#  '*T*-147',
#  'annual',
#  'exploration',
#  'here',
#  'picket',
#  'Ballot',
#  '*T*-169',
#  'soybeans',
#  '500,000',
#  '*T*-159',
#  'collective',
#  'accrued',
#  'aimed',
#  'Separately',
#  '120',
#  'eyeing',
#  "''",
#  'start-up',
#  '890',
#  'scarce',
#  'Companies',
#  'Patrick',
#  'extended',
#  'Sen.',
#  'Temple',
#  'Columbus',
#  'ground',
#  'ending',
#  'R.P.',
#  'bitterness',
#  'client',
#  'emerging',
#  'depository',
#  '--',
#  'red',
#  '30,000',
#  'portray',
#  'declining',
#  '644',
#  'nationalist',
#  'mind',
#  'emerged',
#  'delay',
#  'mine',
#  'Several',
#  'Irvine',
#  'third',
#  'Merc',
#  'minor',
#  'Underwoods',
#  '92.9',
#  'habit',
#  '0.16',
#  '*?*',
#  'University',
#  'full',
#  '150-point',
#  '1\\/10th',
#  '1986-87',
#  'industrialized',
#  '26.5',
#  'Forget',
#  'variation',
#  'R.',
#  'b',
#  'blip',
#  '*T*-200',
#  'estimation',
#  'Palestinian',
#  'Partly',
#  'microcomputers',
#  'odd-year',
#  'south',
#  'career',
#  'again',
#  'signaling',
#  'unwanted',
#  'signifying',
#  'opposes',
#  'assembly',
#  'JUDICIAL',
#  '*T*-184',
#  'dissident',
#  'East',
#  'Scherer',
#  'halt',
#  'office',
#  'outnumbered',
#  'Truck',
#  'test-prep',
#  'Ideas',
#  'Champagne',
#  'artist',
#  'established',
#  'voters',
#  'personnel',
#  'lofty',
#  'pushing',
#  'UNION',
#  'IRS',
#  'PLO',
#  'cost-cutting',
#  'sensitive',
#  'unemployment',
#  'News',
#  'gloss',
#  'inched',
#  'petroleum',
#  'excellence',
#  'Huxtable',
#  'society',
#  'explosive',
#  'scuttle',
#  'profitability',
#  'harm',
#  'fold',
#  'Raton',
#  'disparate',
#  '4',
#  'encourages',
#  'four-foot-high',
#  'placement',
#  'groups',
#  'Test-preparation',
#  'chronicle',
#  'strike',
#  'stare',
#  'exposures',
#  'Plantation',
#  'underpin',
#  'Papua-New',
#  "'ve",
#  '6.6',
#  'Miss.',
#  'founder',
#  'mindful',
#  'direction',
#  'shopping',
#  'Judah',
#  '566.54',
#  '*T*-62',
#  'approximately',
#  '350',
#  'Spirit',
#  'candidates',
#  'CEOs',
#  'driving',
#  'gift',
#  'Abbey',
#  '93',
#  'Nationwide',
#  'windfall',
#  'face',
#  'frustrating',
#  'discussed',
#  'tried',
#  'wants',
#  'ushered',
#  '50\\/50',
#  'understatement',
#  '131.01',
#  'Glenn',
#  'psychiatric',
#  'Journal',
#  'fond',
#  'close-up',
#  'Pepperdine',
#  'locked',
#  '12.5',
#  '1967',
#  'computer',
#  'provided',
#  'impaired',
#  'set',
#  'tramp',
#  'authorities',
#  'leaving',
#  'skyward',
#  'apple',
#  'prestigious',
#  'crackdown',
#  'pro-choice',
#  'Labouisse',
#  'crushed',
#  'skill',
#  'Stockholm',
#  'Fremantle',
#  '372.14',
#  'overhead',
#  'voices',
#  '*T*-250',
#  'longtime',
#  '*T*-234',
#  'deter',
#  'playful',
#  'boilers',
#  'democracy',
#  'creates',
#  'weather',
#  'under',
#  'semiliterate',
#  'February',
#  'framework',
#  'literature',
#  'discuss',
#  'reaffirmed',
#  'domestically',
#  'corkscrews',
#  'COMPUTERS',
#  'Magleby',
#  '93.3',
#  'Claire',
#  'choose',
#  'believes',
#  'promoting',
#  'bread-and-butter',
#  'Groton',
#  'resist',
#  'one',
#  'calculations',
#  'purely',
#  'undergoing',
#  'Wine',
#  '3648.82',
#  '2.35',
#  '*T*-213',
#  'Minneapolis-based',
#  '22\\/32',
#  'years',
#  '*T*-179',
#  'memories',
#  '19-month-old',
#  'riskier',
#  'concentrated',
#  'materialize',
#  'Marchese',
#  'premiums',
#  'pickups',
#  'rich',
#  'population',
#  'happen',
#  'cups',
#  'Marie',
#  'Obligations',
#  'fabricator',
#  'undercutting',
#  'anti-takeover',
#  'Dunton',
#  'experienced',
#  'offset',
#  'sold',
#  'ITC',
#  'softening',
#  'wooing',
#  'biscuit',
#  'valuable',
#  'walk',
#  'duties',
#  'dessert',
#  'challenge',
#  'Grgich',
#  'embassy',
#  'Rothschild',
#  'preferences',
#  'clothes',
#  '275',
#  '81.8',
#  'lunch',
#  'ward',
#  'happy',
#  'savings',
#  'firmness',
#  'wallowing',
#  'inevitable',
#  'coordinator',
#  '109.73',
#  'you',
#  'penalties',
#  'sew',
#  '*T*-246',
#  'bell-ringer',
#  'improper',
#  '7.272',
#  'Buy',
#  'ingredients',
#  'December',
#  'prevents',
#  '*T*-212',
#  'apprehensive',
#  '271-147',
#  'works',
#  '6.21',
#  'processing',
#  'Nemeth',
#  'Datapoint',
#  'block',
#  '*-64',
#  'regions',
#  'decade-long',
#  'Equity',
#  'joint-venture',
#  'Stewart',
#  'decisions',
#  'weakness',
#  'recruited',
#  'plugged',
#  'hot',
#  'widely',
#  '*T*-45',
#  'callers',
#  'utilities',
#  'elementary',
#  'hire',
#  'Posted',
#  'influenced',
#  '*-112',
#  'LATE',
#  'ASSETS',
#  'zinc',
#  'acted',
#  'Puccio',
#  'Carnival',
#  'Wa',
#  'Citizen',
#  'schedule',
#  'dressed',
#  'cope',
#  'Articles',
#  'Huntsville',
#  'Warsaw',
#  'instituted',
#  'specify',
#  'European',
#  'dirtiest',
#  'continuing',
#  'depressions',
#  'eliminating',
#  'hunker',
#  'trailed',
#  'historic',
#  'seats',
#  'Johnny',
#  'effects',
#  'five-day',
#  'suit',
#  'performance',
#  '*T*-164',
#  'buck',
#  'days',
#  'sacked',
#  'lobbyist',
#  'noncompetitively',
#  'gas',
#  'Switzerland',
#  '40-megabyte',
#  '2.46',
#  'we-Japanese',
#  'squeezed',
#  'SALT',
#  'complex',
#  'voting',
#  'invent',
#  'judgments',
#  '*-98',
#  'medical',
#  'attacking',
#  'Standard',
#  'construction',
#  'speculated',
#  'moves',
#  'Leming',
#  'Komatsu',
#  'tobacco',
#  '*-59',
#  'begin',
#  'Metropolitan',
#  'rules',
#  'muster',
#  '57.7',
#  'friendly',
#  'yourself',
#  'Compare',
#  '4,393,237',
#  'ball',
#  'injuries',
#  'Advocates',
#  'redeemed',
#  'cake',
#  'basis',
#  'MacDonald',
#  'rectified',
#  '*-54',
#  '20.5',
#  'removal',
#  'personal',
#  'inside',
#  'aim',
#  'Wu',
#  'emigres',
#  'Agnew',
#  'purchases',
#  'nose',
#  'Carlton',
#  'N.V',
#  'reducing',
#  'Britain',
#  '11\\/16',
#  'milked',
#  'queers',
#  'exceedingly',
#  'implement',
#  'array',
#  'space',
#  'developer',
#  '*-85',
#  'Total',
#  'Young',
#  'Travelers',
#  '497.34',
#  '8.12',
#  '449.04',
#  'painting',
#  'creativity',
#  'auctioned',
#  'liable',
#  'factoring',
#  '374.20',
#  'landfill',
#  'decade',
#  'Chinchon',
#  'Taking',
#  'nail',
#  'OK',
#  'hormone',
#  'unintelligible',
#  '13,056',
#  'Erbamont',
#  'filings',
#  'quotations',
#  '*T*-104',
#  'Devon',
#  'starting',
#  'stupid',
#  'compliance',
#  'Rosenblum',
#  '1970s',
#  'Boone',
#  '5,000',
#  'more-advanced',
#  'shoot',
#  'Sept.',
#  '26.8',
#  'surrender',
#  'avenge',
#  'Year',
#  'Georgia-Pacific',
#  'halve',
#  'appropriate',
#  'FBI',
#  'watching',
#  'Germany-based',
#  'Toledo',
#  'Hitachi',
#  'please',
#  '310',
#  'ratified',
#  'loathsome',
#  'dolls',
#  'Montedison',
#  'HOME',
#  'enraged',
#  'Roman',
#  'specialists',
#  'magnified',
#  '*-40',
#  'Card',
#  'Paso',
#  'views',
#  'Earnings',
#  'colored',
#  '16,000',
#  'revelations',
#  'Rexinger',
#  'examined',
#  '*T*-197',
#  'element',
#  'NATIONAL',
#  'Coleco',
#  'loveliest',
#  'survive',
#  'Education',
#  'confidence',
#  'shortly',
#  'soft',
#  '@',
#  'one-yen',
#  'steep',
#  '36.9',
#  'opens',
#  'cabs',
#  'actual',
#  'Petersen',
#  'equaling',
#  'Legend',
#  'penetration',
#  "'50s",
#  'kind',
#  'sweetened',
#  'Rubicam',
#  'reader',
#  'American',
#  'solid',
#  'legislative',
#  'Editorials',
#  'N.',
#  'possessions',
#  'located',
#  'transactions',
#  'Einhorn',
#  'dreamt',
#  '2,000',
#  'students',
#  'Mutchin',
#  'Revolution',
#  '909',
#  'edged',
#  'basically',
#  'brought',
#  'imaginative',
#  'excise',
#  'III',
#  'shape',
#  'writer',
#  "'m",
#  'proponents',
#  'gut',
#  'editors',
#  'perceived',
#  'fashion',
#  'flows',
#  '*-113',
#  'curtailed',
#  'doctrine',
#  'downgrading',
#  'events',
#  '190',
#  'peak',
#  'asset',
#  'arrangements',
#  'Laboratories',
#  'Alstyne',
#  'across',
#  'Cross',
#  'revenue',
#  'session',
#  'U.S.',
#  'finite',
#  'capitalist',
#  '*T*-120',
#  'Esso',
#  '*T*-100',
#  'p.m.',
#  'read',
#  'Marchand',
#  'Veselich',
#  'prices',
#  'Following',
#  'Coors',
#  'jointly',
#  'husband',
#  'arbs',
#  'disaster',
#  'upward',
#  'cane',
#  'Remember',
#  'highlight',
#  'relationship',
#  'asset-sale',
#  'staid',
#  'skepticism',
#  'Association',
#  'off',
#  '9.82',
#  'Jerritts',
#  'railings',
#  'sellers',
#  'tote',
#  'occurred',
#  'include',
#  'speech',
#  'LANDOR',
#  'Co.',
#  'shrinking',
#  ...]

# %%
# getting unique tags
T = list(set([pair[1] for pair in train_tagged_words]))
T.sort(reverse = True)
T
# Out:
# ['X',
#  'VERB',
#  'PRT',
#  'PRON',
#  'NUM',
#  'NOUN',
#  'DET',
#  'CONJ',
#  'ADV',
#  'ADP',
#  'ADJ',
#  '.']

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# ### Training HMM model using train data

# %%
# Creating function to calculate the emission probabilities P(Wi | Tj) 
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    return (count_w_given_tag, count_tag)

# %%
# Creating function to calculate the transition probabilities or P(T2 | T1)
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# creating t x t transition matrix of tags where each column is t2, each row is t1 where transition probability is P(T2 | T1)
tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
        
# converting the matrix to a dataframe for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))
tags_df
# Out:
#              X      VERB       PRT      PRON       NUM      NOUN       DET  \
# X     0.074433  0.204571  0.184891  0.055705  0.002857  0.062371  0.055229
# VERB  0.218438  0.168744  0.031427  0.035916  0.022448  0.111386  0.133292
# PRT   0.013123  0.405184  0.001969  0.017717  0.056102  0.245735  0.101050
# PRON  0.092720  0.484291  0.012261  0.007663  0.007280  0.211494  0.009195
# NUM   0.211824  0.016934  0.026144  0.001485  0.184195  0.352347  0.003862
# NOUN  0.028868  0.146955  0.043357  0.004721  0.009550  0.264280  0.013363
# DET   0.045323  0.040394  0.000240  0.003727  0.021640  0.637293  0.005771
# CONJ  0.008809  0.155308  0.003709  0.058414  0.042188  0.350487  0.118683
# ADV   0.023302  0.344541  0.014314  0.015646  0.031624  0.031624  0.069907
# ADP   0.034984  0.008481  0.001484  0.069119  0.061910  0.321213  0.323969
# ADJ   0.020311  0.011794  0.010156  0.000491  0.020803  0.700901  0.004914
# .     0.026908  0.088708  0.002511  0.065208  0.081353  0.222531  0.173558
#
#           CONJ       ADV       ADP       ADJ         .
# X     0.010316  0.025393  0.144898  0.016505  0.162831
# VERB  0.005186  0.082050  0.091184  0.065640  0.034291
# PRT   0.002297  0.010171  0.019357  0.083661  0.043635
# PRON  0.004981  0.034100  0.023372  0.072031  0.040613
# NUM   0.013072  0.002674  0.035056  0.033571  0.118835
# NOUN  0.042921  0.016813  0.177058  0.012165  0.239951
# DET   0.000481  0.012623  0.009618  0.204977  0.017913
# CONJ  0.000464  0.053778  0.053778  0.118683  0.035698
# ADV   0.006991  0.077230  0.119507  0.130160  0.135153
# ADP   0.000848  0.013357  0.017492  0.107389  0.039754
# ADJ   0.016052  0.004914  0.078624  0.067158  0.063882
# .     0.058032  0.052292  0.092206  0.043681  0.092923

# %% [markdown]
# ### Building the vanilla Viterbi based POS tagger

# %%
# Creating function for Viterbi algorithm for tagging sequence of words of a sentence
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    T.sort(reverse=True)
    for key, word in enumerate(words):
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
            # computing emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# evaluating the accuracy of the Viterbi algorithm on the test dataset

# getting list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# getting list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# tagging the test sentences
tagged_seq = Viterbi(test_tagged_words)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy_vnila_viterbi = len(check)/len(tagged_seq)
accuracy_vnila_viterbi
# Out:
# 0.905013750793315

# %%
# counting similar predicted tag that belongs to most of the unknown words
unknown_word_tag = [i for i, j in zip(tagged_seq, test_run_base) if i != j] 
unknown_tag=[]
for i in unknown_word_tag:
    unknown_tag.append(i[1])
Counter(unknown_tag).most_common()
# Out:
# [('X', 297),
#  ('NOUN', 36),
#  ('ADJ', 31),
#  ('VERB', 27),
#  ('ADP', 26),
#  ('ADV', 12),
#  ('PRT', 10),
#  ('DET', 7),
#  ('PRON', 2),
#  ('NUM', 1)]

# %% [markdown]
# Most of the predicted tags are 'X' for unknown words because 'X' is the first tag in unique tag list T.

# %%
# counting similar actual tag that predicted incorrectly only for unknown words
actual_word_tag = [j for i, j in zip(tagged_seq, test_run_base) if i != j and i[1] == T[0]] 
actual_tag=[]
for j in actual_word_tag:
    actual_tag.append(j[1])
Counter(actual_tag).most_common()
# Out:
# [('NOUN', 151),
#  ('VERB', 55),
#  ('ADJ', 51),
#  ('NUM', 34),
#  ('ADV', 4),
#  ('DET', 1),
#  ('ADP', 1)]

# %% [markdown]
# Most of the actual tags that predicted incorrectly are 'NOUN'.

# %%
# checking unknown words with actual tag that predicted incorrectly
actual_word_tag = [j for i, j in zip(tagged_seq, test_run_base) if i != j and i[1] == T[0]] 
actual_word_tag
# Out:
# [('ignored', 'VERB'),
#  ('Preston', 'NOUN'),
#  ('Birmingham', 'NOUN'),
#  ('Ala', 'NOUN'),
#  ('clamped', 'VERB'),
#  ('ankle', 'NOUN'),
#  ('third-largest', 'ADJ'),
#  ('fifth-largest', 'ADJ'),
#  ('Z.', 'NOUN'),
#  ('Wick', 'NOUN'),
#  ('89.7', 'NUM'),
#  ('141.9', 'NUM'),
#  ('94.8', 'NUM'),
#  ('149.9', 'NUM'),
#  ('argues', 'VERB'),
#  ('Sit', 'VERB'),
#  ('athletic', 'ADJ'),
#  ('illustrates', 'VERB'),
#  ('usurp', 'VERB'),
#  ('609', 'NUM'),
#  ('executive-office', 'NOUN'),
#  ('administer', 'VERB'),
#  ('disapproved', 'VERB'),
#  ('disapproval', 'NOUN'),
#  ('accordance', 'NOUN'),
#  ('applicable', 'ADJ'),
#  ('Mead', 'NOUN'),
#  ('Paper', 'NOUN'),
#  ('Paper', 'NOUN'),
#  ('Paper', 'NOUN'),
#  ('Louisiana-Pacific', 'NOUN'),
#  ('Five', 'NUM'),
#  ('DeFazio', 'NOUN'),
#  ('criteria', 'NOUN'),
#  ('Proper', 'ADJ'),
#  ('rounds', 'NOUN'),
#  ('highest-pitched', 'ADJ'),
#  ('descending', 'VERB'),
#  ('62-year-old', 'ADJ'),
#  ('forest-product', 'NOUN'),
#  ('unsolicited', 'ADJ'),
#  ('3.19', 'NUM'),
#  ('impressive', 'ADJ'),
#  ('29year', 'ADJ'),
#  ('nine-month', 'ADJ'),
#  ('ECONOMIC', 'ADJ'),
#  ('GROWTH', 'NOUN'),
#  ('APPEARS', 'VERB'),
#  ('S.A', 'NOUN'),
#  ('U.S.-Japanese', 'ADJ'),
#  ('behemoth', 'NOUN'),
#  ('hotels', 'NOUN'),
#  ('masters', 'NOUN'),
#  ('Tiny', 'NOUN'),
#  ('Tots', 'NOUN'),
#  ('Kelli', 'NOUN'),
#  ('Green', 'NOUN'),
#  ('speculate', 'VERB'),
#  ('yen-support', 'ADJ'),
#  ('intervention', 'NOUN'),
#  ('150.00', 'NUM'),
#  ('smiles', 'NOUN'),
#  ('Mont', 'NOUN'),
#  ('exits', 'NOUN'),
#  ('pushes', 'VERB'),
#  ('Left', 'VERB'),
#  ('Sandoz', 'NOUN'),
#  ('preclinical', 'ADJ'),
#  ('vague', 'ADJ'),
#  ('mushy', 'ADJ'),
#  ('viewpoints', 'NOUN'),
#  ('le', 'DET'),
#  ('115', 'NUM'),
#  ('genie', 'NOUN'),
#  ('len', 'NOUN'),
#  ('foldability', 'NOUN'),
#  ('inserted', 'VERB'),
#  ('incisions', 'NOUN'),
#  ('eye', 'NOUN'),
#  ('ethanol', 'NOUN'),
#  ('fleet', 'NOUN'),
#  ('Lucille', 'NOUN'),
#  ('84-year-old', 'ADJ'),
#  ('housewife', 'NOUN'),
#  ('amazingly', 'ADV'),
#  ('jolts', 'NOUN'),
#  ('DISCOUNT', 'NOUN'),
#  ('sight', 'NOUN'),
#  ('Kirkpatrick', 'NOUN'),
#  ('Sumitomo', 'NOUN'),
#  ('Metal', 'NOUN'),
#  ('692', 'NUM'),
#  ('960', 'NUM'),
#  ('51.6', 'NUM'),
#  ('readings', 'NOUN'),
#  ('wrestling', 'VERB'),
#  ('intelligent', 'ADJ'),
#  ('insane', 'ADJ'),
#  ('tailor-made', 'ADJ'),
#  ('purhasing', 'NOUN'),
#  ('movies', 'NOUN'),
#  ('Peck', 'NOUN'),
#  ('marvelously', 'ADV'),
#  ('loose', 'ADJ'),
#  ('portrayal', 'NOUN'),
#  ('Cataracts', 'NOUN'),
#  ('refer', 'VERB'),
#  ('clouding', 'NOUN'),
#  ('eye', 'NOUN'),
#  ('maturing', 'VERB'),
#  ('filled', 'VERB'),
#  ('solemn', 'ADJ'),
#  ('intoxication', 'NOUN'),
#  ('intricate', 'ADJ'),
#  ('ritual', 'NOUN'),
#  ('faultlessly', 'ADV'),
#  ('properties', 'NOUN'),
#  ('Indexing', 'NOUN'),
#  ('barometer', 'NOUN'),
#  ('crying', 'VERB'),
#  ('Ilminster', 'NOUN'),
#  ('Somerset', 'NOUN'),
#  ('dust-up', 'NOUN'),
#  ('attendance', 'NOUN'),
#  ('8.75', 'NUM'),
#  ('shown', 'VERB'),
#  ('Video', 'NOUN'),
#  ('Tip', 'NOUN'),
#  ('finest', 'ADJ'),
#  ('472', 'NUM'),
#  ('defeats', 'VERB'),
#  ('inkling', 'NOUN'),
#  ('underprivileged', 'ADJ'),
#  ('prosecutor', 'NOUN'),
#  ('alumni', 'NOUN'),
#  ('cultivated', 'VERB'),
#  ('savvier', 'ADJ'),
#  ('burned', 'VERB'),
#  ('wrath', 'NOUN'),
#  ('Californian', 'NOUN'),
#  ('Bolivia', 'NOUN'),
#  ('broadened', 'VERB'),
#  ('initiate', 'NOUN'),
#  ('R.D.', 'NOUN'),
#  ('Vos', 'NOUN'),
#  ('N.Y', 'NOUN'),
#  ('delayed', 'VERB'),
#  ('Above', 'ADP'),
#  ('accountants', 'NOUN'),
#  ('blinks', 'VERB'),
#  ('eye', 'NOUN'),
#  ('abortion-related', 'ADJ'),
#  ('dreamed', 'VERB'),
#  ('improbable', 'ADJ'),
#  ('shop', 'NOUN'),
#  ('high-rise', 'ADJ'),
#  ('diagram', 'NOUN'),
#  ('arrows', 'NOUN'),
#  ('polystyrene', 'NOUN'),
#  ('foam', 'NOUN'),
#  ('polyproplene', 'NOUN'),
#  ('polyester', 'NOUN'),
#  ('non-biodegradable', 'ADJ'),
#  ('seventh', 'ADJ'),
#  ("'82", 'NUM'),
#  ('115', 'NUM'),
#  ('Researchers', 'NOUN'),
#  ('unwilling', 'ADJ'),
#  ('manpower', 'NOUN'),
#  ('removing', 'VERB'),
#  ('safeguarding', 'VERB'),
#  ('Anku', 'NOUN'),
#  ('Ketchum', 'NOUN'),
#  ('Braun', 'NOUN'),
#  ('investor-relations', 'NOUN'),
#  ('marketing-communications', 'NOUN'),
#  ('headed', 'VERB'),
#  ('curbed', 'VERB'),
#  ('leveraging', 'VERB'),
#  ('owning', 'VERB'),
#  ('flirted', 'VERB'),
#  ('father-in-law', 'NOUN'),
#  ('Gardner', 'NOUN'),
#  ('Hubbard', 'NOUN'),
#  ('wealthy', 'ADJ'),
#  ('well-connected', 'ADJ'),
#  ('Moon', 'NOUN'),
#  ('Landrieu', 'NOUN'),
#  ('cavernous', 'ADJ'),
#  ('money-losing', 'ADJ'),
#  ('relevance', 'NOUN'),
#  ('143.93', 'NUM'),
#  ('143.08', 'NUM'),
#  ('cleanup', 'NOUN'),
#  ('burn', 'VERB'),
#  ('cleaner-burning', 'ADJ'),
#  ('fuels', 'NOUN'),
#  ('858,000', 'NUM'),
#  ('overvalued', 'VERB'),
#  ('Paris', 'NOUN'),
#  ('Brussels', 'NOUN'),
#  ('Milan', 'NOUN'),
#  ('discretion', 'NOUN'),
#  ('select', 'VERB'),
#  ('306', 'NUM'),
#  ('unrestricted', 'ADJ'),
#  ('tempted', 'VERB'),
#  ('glory', 'NOUN'),
#  ('faded', 'VERB'),
#  ('yellow', 'ADJ'),
#  ('bricks', 'NOUN'),
#  ('facade', 'NOUN'),
#  ('550,000', 'NUM'),
#  ('Four', 'NUM'),
#  ('diagnosed', 'VERB'),
#  ('27-year', 'ADJ'),
#  ('information-services', 'NOUN'),
#  ('1997', 'NUM'),
#  ('cancer-causing', 'ADJ'),
#  ('outlawed', 'VERB'),
#  ('stemmed', 'VERB'),
#  ('directorship', 'NOUN'),
#  ('Silverman', 'NOUN'),
#  ('insurance-company', 'NOUN'),
#  ('jeopardy', 'NOUN'),
#  ('NEW', 'NOUN'),
#  ('ACCOUNT', 'NOUN'),
#  ('14.75', 'NUM'),
#  ('Chilver', 'NOUN'),
#  ('63-year-old', 'ADJ'),
#  ('Clays', 'NOUN'),
#  ('CoreStates', 'NOUN'),
#  ('Earle', 'NOUN'),
#  ('Palmer', 'NOUN'),
#  ('Spiro', 'NOUN'),
#  ('escape', 'NOUN'),
#  ('insanity', 'NOUN'),
#  ('heirs', 'NOUN'),
#  ('Nylev', 'NOUN'),
#  ('malnutrition', 'NOUN'),
#  ('chest', 'NOUN'),
#  ('cardiovascular', 'ADJ'),
#  ('infectious', 'ADJ'),
#  ('aftereffects', 'NOUN'),
#  ('assaults', 'NOUN'),
#  ('grandstander', 'NOUN'),
#  ('luxury', 'NOUN'),
#  ('879', 'NUM'),
#  ('13.90', 'NUM'),
#  ('shopped', 'VERB'),
#  ('espouse', 'VERB'),
#  ('deteriorating', 'VERB'),
#  ('Anderson', 'NOUN'),
#  ('59-year-old', 'ADJ'),
#  ('fluctuations', 'NOUN'),
#  ('heebie-jeebies', 'NOUN'),
#  ('outlawing', 'VERB'),
#  ('display', 'VERB'),
#  ('projector', 'NOUN'),
#  ('underline', 'VERB'),
#  ('Old-House', 'NOUN'),
#  ('126,000', 'NUM'),
#  ('round-trip', 'ADJ'),
#  ('Trans', 'NOUN'),
#  ('luxury', 'NOUN'),
#  ('soaring', 'VERB'),
#  ('reclaimed', 'VERB'),
#  ('240-page', 'ADJ'),
#  ('Iran-Contra', 'NOUN'),
#  ('221.4', 'NUM'),
#  ('Next', 'ADJ'),
#  ('Philippine', 'NOUN'),
#  ('Philippine', 'ADJ'),
#  ('Corazon', 'NOUN'),
#  ('Aquino', 'NOUN'),
#  ('midyear', 'NOUN'),
#  ('Spending', 'NOUN'),
#  ('nonresidential', 'ADJ'),
#  ('99.1', 'NUM'),
#  ('awaits', 'VERB'),
#  ('Aerospace', 'NOUN'),
#  ('sagged', 'VERB'),
#  ('bombers', 'NOUN'),
#  ('88.32', 'NUM'),
#  ('618.1', 'NUM'),
#  ('77.6', 'NUM'),
#  ('12.52', 'NUM'),
#  ('11.95', 'NUM'),
#  ('shipboard', 'NOUN'),
#  ('Malta', 'NOUN'),
#  ('NCNB', 'NOUN'),
#  ('Connections', 'NOUN'),
#  ('adults', 'NOUN'),
#  ('broadly', 'ADV'),
#  ('construed', 'VERB'),
#  ('emasculate', 'VERB'),
#  ('swallow', 'VERB')]

# %% [markdown]
# As we can see above that:
# - Unknown words such as names of person, places etc. for example 'Wick', 'Preston', 'Birmingham' etc should be tagged as 'NOUN'.
# - Unknown words such as words having suffix(ed, ing etc.), for example 'ignored', 'clamped', 'disapproved', 'wrestling', 'maturing' etc should be tagged as 'VERB'.
# - Unknown words such as words having suffix(est, er, ive, ent etc.), for example 'third-largest', 'fifth-largest', 'Proper', 'impressive',  'intelligent' etc should be tagged as 'ADJ'.
# - Unknown words such as numbers, for example '89.7', '141.9', '94.8', '692' etc should be tagged as 'NUM'.
# - Unknown words such as words having suffix(ly etc.), for example 'marvelously', 'faultlessly', 'broadly' etc should be tagged as 'ADV'.

# %%
# incorrect tagged word with correct tagged word, previous correct tagged word and next correct tagged word
# [(previous correct tagged word), ((incorrect tagged word), (correct tagged word)), (previous correct tagged word)]
incorrect_tagged_cases = [[test_run_base[i-1],j,test_run_base[i+1]] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1] and j[0][1] == T[0]]
incorrect_tagged_cases
# Out:
# [[('apparently', 'ADV'),
#   (('ignored', 'X'), ('ignored', 'VERB')),
#   ('reports', 'NOUN')],
#  [('.', '.'), (('Preston', 'X'), ('Preston', 'NOUN')), ('G.', 'NOUN')],
#  [('Foster', 'NOUN'),
#   (('Birmingham', 'X'), ('Birmingham', 'NOUN')),
#   (',', '.')],
#  [(',', '.'), (('Ala', 'X'), ('Ala', 'NOUN')), ('.', '.')],
#  [('has', 'VERB'), (('clamped', 'X'), ('clamped', 'VERB')), ('on', 'ADP')],
#  [('their', 'PRON'), (('ankle', 'X'), ('ankle', 'NOUN')), ('like', 'ADP')],
#  [('the', 'DET'),
#   (('third-largest', 'X'), ('third-largest', 'ADJ')),
#   ('producer', 'NOUN')],
#  [('the', 'DET'),
#   (('fifth-largest', 'X'), ('fifth-largest', 'ADJ')),
#   ('exporter', 'NOUN')],
#  [('Charles', 'NOUN'), (('Z.', 'X'), ('Z.', 'NOUN')), ('Wick', 'NOUN')],
#  [('Z.', 'NOUN'), (('Wick', 'X'), ('Wick', 'NOUN')), ('.', '.')],
#  [('#', '.'), (('89.7', 'X'), ('89.7', 'NUM')), ('million', 'NUM')],
#  [('$', '.'), (('141.9', 'X'), ('141.9', 'NUM')), ('million', 'NUM')],
#  [('#', '.'), (('94.8', 'X'), ('94.8', 'NUM')), ('million', 'NUM')],
#  [('$', '.'), (('149.9', 'X'), ('149.9', 'NUM')), ('million', 'NUM')],
#  [('he', 'PRON'), (('argues', 'X'), ('argues', 'VERB')), ('0', 'X')],
#  [('*', 'X'), (('Sit', 'X'), ('Sit', 'VERB')), ('down', 'ADV')],
#  [('as', 'ADP'),
#   (('athletic', 'X'), ('athletic', 'ADJ')),
#   ('activities', 'NOUN')],
#  [('*ICH*-1', 'X'),
#   (('illustrates', 'X'), ('illustrates', 'VERB')),
#   ('Congress', 'NOUN')],
#  [('to', 'PRT'), (('usurp', 'X'), ('usurp', 'VERB')), ('executive', 'ADJ')],
#  [('Section', 'NOUN'), (('609', 'X'), ('609', 'NUM')), ('of', 'ADP')],
#  [('the', 'DET'),
#   (('executive-office', 'X'), ('executive-office', 'NOUN')),
#   ('bill', 'NOUN')],
#  [(',', '.'), (('administer', 'X'), ('administer', 'VERB')), (',', '.')],
#  [('been', 'VERB'),
#   (('disapproved', 'X'), ('disapproved', 'VERB')),
#   ('*-58', 'X')],
#  [('of', 'ADP'),
#   (('disapproval', 'X'), ('disapproval', 'NOUN')),
#   ('duly', 'ADV')],
#  [('in', 'ADP'),
#   (('accordance', 'X'), ('accordance', 'NOUN')),
#   ('with', 'ADP')],
#  [('the', 'DET'),
#   (('applicable', 'X'), ('applicable', 'ADJ')),
#   ('law', 'NOUN')],
#  [("''", '.'), (('Mead', 'X'), ('Mead', 'NOUN')), ('rose', 'VERB')],
#  [('Federal', 'NOUN'), (('Paper', 'X'), ('Paper', 'NOUN')), ('Board', 'NOUN')],
#  [('Scott', 'NOUN'), (('Paper', 'X'), ('Paper', 'NOUN')), ('gained', 'VERB')],
#  [('International', 'NOUN'),
#   (('Paper', 'X'), ('Paper', 'NOUN')),
#   ('fell', 'VERB')],
#  [('and', 'CONJ'),
#   (('Louisiana-Pacific', 'X'), ('Louisiana-Pacific', 'NOUN')),
#   ('dropped', 'VERB')],
#  [('.', '.'), (('Five', 'X'), ('Five', 'NUM')), ('things', 'NOUN')],
#  [('Peter', 'NOUN'), (('DeFazio', 'X'), ('DeFazio', 'NOUN')), ('-LRB-', '.')],
#  [('previous', 'ADJ'), (('criteria', 'X'), ('criteria', 'NOUN')), (',', '.')],
#  [('.', '.'), (('Proper', 'X'), ('Proper', 'ADJ')), ('English', 'ADJ')],
#  [('``', '.'), (('rounds', 'X'), ('rounds', 'NOUN')), (',', '.')],
#  [('the', 'DET'),
#   (('highest-pitched', 'X'), ('highest-pitched', 'ADJ')),
#   ('bell', 'NOUN')],
#  [('simple', 'ADJ'),
#   (('descending', 'X'), ('descending', 'VERB')),
#   ('scale', 'NOUN')],
#  [('the', 'DET'),
#   (('62-year-old', 'X'), ('62-year-old', 'ADJ')),
#   ('chairman', 'NOUN')],
#  [('the', 'DET'),
#   (('forest-product', 'X'), ('forest-product', 'NOUN')),
#   ('concern', 'NOUN')],
#  [("'s", 'PRT'), (('unsolicited', 'X'), ('unsolicited', 'ADJ')), ('$', '.')],
#  [('$', '.'), (('3.19', 'X'), ('3.19', 'NUM')), ('billion', 'NUM')],
#  [('that', 'DET'), (('impressive', 'X'), ('impressive', 'ADJ')), (',', '.')],
#  [('of', 'ADP'), (('29year', 'X'), ('29year', 'ADJ')), (',', '.')],
#  [(',', '.'), (('nine-month', 'X'), ('nine-month', 'ADJ')), ('bonds', 'NOUN')],
#  [('.', '.'), (('ECONOMIC', 'X'), ('ECONOMIC', 'ADJ')), ('GROWTH', 'NOUN')],
#  [('ECONOMIC', 'ADJ'),
#   (('GROWTH', 'X'), ('GROWTH', 'NOUN')),
#   ('APPEARS', 'VERB')],
#  [('GROWTH', 'NOUN'), (('APPEARS', 'X'), ('APPEARS', 'VERB')), ('*-1', 'X')],
#  [('Michelin', 'NOUN'), (('S.A', 'X'), ('S.A', 'NOUN')), ('.', '.')],
#  [(',', '.'),
#   (('U.S.-Japanese', 'X'), ('U.S.-Japanese', 'ADJ')),
#   ('relations', 'NOUN')],
#  [('economic', 'ADJ'), (('behemoth', 'X'), ('behemoth', 'NOUN')), ('.', '.')],
#  [('operates', 'VERB'), (('hotels', 'X'), ('hotels', 'NOUN')), (',', '.')],
#  [('by', 'ADP'), (('masters', 'X'), ('masters', 'NOUN')), ('such', 'ADJ')],
#  [('.', '.'), (('Tiny', 'X'), ('Tiny', 'NOUN')), ('Tots', 'NOUN')],
#  [('Tiny', 'NOUN'), (('Tots', 'X'), ('Tots', 'NOUN')), ('Inc.', 'NOUN')],
#  [('*T*-2', 'X'), (('Kelli', 'X'), ('Kelli', 'NOUN')), ('Green', 'NOUN')],
#  [('Kelli', 'NOUN'), (('Green', 'X'), ('Green', 'NOUN')), (',', '.')],
#  [('to', 'PRT'),
#   (('speculate', 'X'), ('speculate', 'VERB')),
#   ('about', 'ADP')],
#  [('Japan', 'NOUN'),
#   (('yen-support', 'X'), ('yen-support', 'ADJ')),
#   ('intervention', 'NOUN')],
#  [('yen-support', 'ADJ'),
#   (('intervention', 'X'), ('intervention', 'NOUN')),
#   ('since', 'ADP')],
#  [('the', 'DET'), (('150.00', 'X'), ('150.00', 'NUM')), ('yen', 'NOUN')],
#  [('no', 'DET'), (('smiles', 'X'), ('smiles', 'NOUN')), ('about', 'ADP')],
#  [(',', '.'), (('Mont', 'X'), ('Mont', 'NOUN')), ('.', '.')],
#  [('the', 'DET'), (('exits', 'X'), ('exits', 'NOUN')), ('if', 'ADP')],
#  [('rebound', 'NOUN'), (('pushes', 'X'), ('pushes', 'VERB')), ('the', 'DET')],
#  [('*-1', 'X'), (('Left', 'X'), ('Left', 'VERB')), ('*-3', 'X')],
#  [('.', '.'), (('Sandoz', 'X'), ('Sandoz', 'NOUN')), ('Ltd.', 'NOUN')],
#  [('conducting', 'VERB'),
#   (('preclinical', 'X'), ('preclinical', 'ADJ')),
#   ('studies', 'NOUN')],
#  [('``', '.'), (('vague', 'X'), ('vague', 'ADJ')), ('and', 'CONJ')],
#  [('and', 'CONJ'), (('mushy', 'X'), ('mushy', 'ADJ')), ("''", '.')],
#  [('all', 'DET'),
#   (('viewpoints', 'X'), ('viewpoints', 'NOUN')),
#   ('could', 'VERB')],
#  [('Salon', 'NOUN'), (('le', 'X'), ('le', 'DET')), ('Mesnil', 'NOUN')],
#  [('$', '.'), (('115', 'X'), ('115', 'NUM')), ('*U*', 'X')],
#  [('the', 'DET'), (('genie', 'X'), ('genie', 'NOUN')), ('back', 'ADV')],
#  [('The', 'DET'), (('len', 'X'), ('len', 'NOUN')), ("'s", 'PRT')],
#  [("'s", 'PRT'),
#   (('foldability', 'X'), ('foldability', 'NOUN')),
#   ('enables', 'VERB')],
#  [('be', 'VERB'), (('inserted', 'X'), ('inserted', 'VERB')), ('*-1', 'X')],
#  [('smaller', 'ADJ'),
#   (('incisions', 'X'), ('incisions', 'NOUN')),
#   ('than', 'ADP')],
#  [('the', 'DET'), (('eye', 'X'), ('eye', 'NOUN')), ('care', 'NOUN')],
#  [('an', 'DET'), (('ethanol', 'X'), ('ethanol', 'NOUN')), ('program', 'NOUN')],
#  [('national', 'ADJ'), (('fleet', 'X'), ('fleet', 'NOUN')), ('of', 'ADP')],
#  [('.', '.'), (('Lucille', 'X'), ('Lucille', 'NOUN')), ('Gorman', 'NOUN')],
#  [('an', 'DET'),
#   (('84-year-old', 'X'), ('84-year-old', 'ADJ')),
#   ('Chicago', 'NOUN')],
#  [('Chicago', 'NOUN'),
#   (('housewife', 'X'), ('housewife', 'NOUN')),
#   (',', '.')],
#  [('become', 'VERB'),
#   (('amazingly', 'X'), ('amazingly', 'ADV')),
#   ('immune', 'ADJ')],
#  [('stock-market', 'NOUN'), (('jolts', 'X'), ('jolts', 'NOUN')), ('.', '.')],
#  [('.', '.'), (('DISCOUNT', 'X'), ('DISCOUNT', 'NOUN')), ('RATE', 'NOUN')],
#  [('in', 'ADP'), (('sight', 'X'), ('sight', 'NOUN')), (',', '.')],
#  [('Ms.', 'NOUN'),
#   (('Kirkpatrick', 'X'), ('Kirkpatrick', 'NOUN')),
#   (',', '.')],
#  [('.', '.'), (('Sumitomo', 'X'), ('Sumitomo', 'NOUN')), ('Metal', 'NOUN')],
#  [('Sumitomo', 'NOUN'),
#   (('Metal', 'X'), ('Metal', 'NOUN')),
#   ('Mining', 'NOUN')],
#  [('to', 'PRT'), (('692', 'X'), ('692', 'NUM')), ('and', 'CONJ')],
#  [('to', 'PRT'), (('960', 'X'), ('960', 'NUM')), ('.', '.')],
#  [('to', 'PRT'), (('51.6', 'X'), ('51.6', 'NUM')), ('%', 'NOUN')],
#  [('of', 'ADP'), (('readings', 'X'), ('readings', 'NOUN')), ('below', 'ADP')],
#  [('is', 'VERB'),
#   (('wrestling', 'X'), ('wrestling', 'VERB')),
#   ('with', 'ADP')],
#  [('especially', 'ADV'),
#   (('intelligent', 'X'), ('intelligent', 'ADJ')),
#   ('or', 'CONJ')],
#  [('temporarily', 'ADV'), (('insane', 'X'), ('insane', 'ADJ')), ('.', '.')],
#  [('seem', 'VERB'),
#   (('tailor-made', 'X'), ('tailor-made', 'ADJ')),
#   ('for', 'ADP')],
#  [('The', 'DET'),
#   (('purhasing', 'X'), ('purhasing', 'NOUN')),
#   ('managers', 'NOUN')],
#  [('bad', 'ADJ'), (('movies', 'X'), ('movies', 'NOUN')), ('have', 'VERB')],
#  [('Gregory', 'NOUN'), (('Peck', 'X'), ('Peck', 'NOUN')), (',', '.')],
#  [('a', 'DET'),
#   (('marvelously', 'X'), ('marvelously', 'ADV')),
#   ('loose', 'ADJ')],
#  [('marvelously', 'ADV'), (('loose', 'X'), ('loose', 'ADJ')), ('and', 'CONJ')],
#  [('energetic', 'ADJ'),
#   (('portrayal', 'X'), ('portrayal', 'NOUN')),
#   ('of', 'ADP')],
#  [('.', '.'), (('Cataracts', 'X'), ('Cataracts', 'NOUN')), ('refer', 'VERB')],
#  [('Cataracts', 'NOUN'), (('refer', 'X'), ('refer', 'VERB')), ('to', 'PRT')],
#  [('a', 'DET'), (('clouding', 'X'), ('clouding', 'NOUN')), ('of', 'ADP')],
#  [('the', 'DET'), (('eye', 'X'), ('eye', 'NOUN')), ("'s", 'PRT')],
#  [('in', 'ADP'), (('maturing', 'X'), ('maturing', 'VERB')), ('notes', 'NOUN')],
#  [('``', '.'), (('filled', 'X'), ('filled', 'VERB')), ('*-1', 'X')],
#  [('the', 'DET'),
#   (('solemn', 'X'), ('solemn', 'ADJ')),
#   ('intoxication', 'NOUN')],
#  [('solemn', 'ADJ'),
#   (('intoxication', 'X'), ('intoxication', 'NOUN')),
#   ('that', 'DET')],
#  [('of', 'ADP'),
#   (('intricate', 'X'), ('intricate', 'ADJ')),
#   ('ritual', 'NOUN')],
#  [('intricate', 'ADJ'),
#   (('ritual', 'X'), ('ritual', 'NOUN')),
#   ('faultlessly', 'ADV')],
#  [('ritual', 'NOUN'),
#   (('faultlessly', 'X'), ('faultlessly', 'ADV')),
#   ('performed', 'VERB')],
#  [('questionable', 'ADJ'),
#   (('properties', 'X'), ('properties', 'NOUN')),
#   ('.', '.')],
#  [('.', '.'), (('Indexing', 'X'), ('Indexing', 'NOUN')), ('--', '.')],
#  [('stock-market', 'NOUN'),
#   (('barometer', 'X'), ('barometer', 'NOUN')),
#   ('such', 'ADJ')],
#  [('people', 'NOUN'), (('crying', 'X'), ('crying', 'VERB')), ('in', 'ADP')],
#  [('in', 'ADP'), (('Ilminster', 'X'), ('Ilminster', 'NOUN')), (',', '.')],
#  [(',', '.'), (('Somerset', 'X'), ('Somerset', 'NOUN')), (',', '.')],
#  [('a', 'DET'), (('dust-up', 'X'), ('dust-up', 'NOUN')), ('over', 'ADP')],
#  [('church', 'NOUN'),
#   (('attendance', 'X'), ('attendance', 'NOUN')),
#   ('.', '.')],
#  [('to', 'PRT'), (('8.75', 'X'), ('8.75', 'NUM')), ('%', 'NOUN')],
#  [('has', 'VERB'), (('shown', 'X'), ('shown', 'VERB')), ('no', 'DET')],
#  [('.', '.'), (('Video', 'X'), ('Video', 'NOUN')), ('Tip', 'NOUN')],
#  [('Video', 'NOUN'), (('Tip', 'X'), ('Tip', 'NOUN')), (':', '.')],
#  [('his', 'PRON'), (('finest', 'X'), ('finest', 'ADJ')), ('.', '.')],
#  [('$', '.'), (('472', 'X'), ('472', 'NUM')), ('million', 'NUM')],
#  [('much', 'ADV'), (('defeats', 'X'), ('defeats', 'VERB')), ('any', 'DET')],
#  [('any', 'DET'), (('inkling', 'X'), ('inkling', 'NOUN')), ('that', 'ADP')],
#  [('poor', 'ADJ'),
#   (('underprivileged', 'X'), ('underprivileged', 'ADJ')),
#   ('child', 'NOUN')],
#  [('the', 'DET'),
#   (('prosecutor', 'X'), ('prosecutor', 'NOUN')),
#   ('in', 'ADP')],
#  [("'s", 'PRT'),
#   (('alumni', 'X'), ('alumni', 'NOUN')),
#   ('association', 'NOUN')],
#  [('has', 'VERB'),
#   (('cultivated', 'X'), ('cultivated', 'VERB')),
#   ('a', 'DET')],
#  [('much', 'ADV'),
#   (('savvier', 'X'), ('savvier', 'ADJ')),
#   ('consumer', 'NOUN')],
#  [('get', 'VERB'), (('burned', 'X'), ('burned', 'VERB')), ('*-1', 'X')],
#  [('their', 'PRON'), (('wrath', 'X'), ('wrath', 'NOUN')), ('?', '.')],
#  [('conservative', 'ADJ'),
#   (('Californian', 'X'), ('Californian', 'NOUN')),
#   (',', '.')],
#  [('assist', 'VERB'), (('Bolivia', 'X'), ('Bolivia', 'NOUN')), (',', '.')],
#  [('then', 'ADV'),
#   (('broadened', 'X'), ('broadened', 'VERB')),
#   ('the', 'DET')],
#  [('Basin', 'NOUN'), (('initiate', 'X'), ('initiate', 'NOUN')), ('as', 'ADV')],
#  [('Maxwell', 'NOUN'), (('R.D.', 'X'), ('R.D.', 'NOUN')), ('Vos', 'NOUN')],
#  [('R.D.', 'NOUN'), (('Vos', 'X'), ('Vos', 'NOUN')), ('Brooklyn', 'NOUN')],
#  [(',', '.'), (('N.Y', 'X'), ('N.Y', 'NOUN')), ('.', '.')],
#  [('were', 'VERB'), (('delayed', 'X'), ('delayed', 'VERB')), ('*-1', 'X')],
#  [('.', '.'), (('Above', 'X'), ('Above', 'ADP')), ('all', 'DET')],
#  [('or', 'CONJ'),
#   (('accountants', 'X'), ('accountants', 'NOUN')),
#   ('...', '.')],
#  [('nobody', 'NOUN'), (('blinks', 'X'), ('blinks', 'VERB')), ('an', 'DET')],
#  [('an', 'DET'), (('eye', 'X'), ('eye', 'NOUN')), ('.', '.')],
#  [('include', 'VERB'),
#   (('abortion-related', 'X'), ('abortion-related', 'ADJ')),
#   ('services', 'NOUN')],
#  [('Lane', 'NOUN'), (('dreamed', 'X'), ('dreamed', 'VERB')), ('up', 'PRT')],
#  [('highly', 'ADV'),
#   (('improbable', 'X'), ('improbable', 'ADJ')),
#   ('romance', 'NOUN')],
#  [("'s", 'PRT'), (('shop', 'X'), ('shop', 'NOUN')), ('and', 'CONJ')],
#  [('expensive', 'ADJ'),
#   (('high-rise', 'X'), ('high-rise', 'ADJ')),
#   ('apartment', 'NOUN')],
#  [('giant', 'ADJ'), (('diagram', 'X'), ('diagram', 'NOUN')), ('of', 'ADP')],
#  [('with', 'ADP'),
#   (('arrows', 'X'), ('arrows', 'NOUN')),
#   ('pointing', 'VERB')],
#  [("'s", 'PRT'),
#   (('polystyrene', 'X'), ('polystyrene', 'NOUN')),
#   ('foam', 'NOUN')],
#  [('polystyrene', 'NOUN'), (('foam', 'X'), ('foam', 'NOUN')), (',', '.')],
#  [(',', '.'),
#   (('polyproplene', 'X'), ('polyproplene', 'NOUN')),
#   ('and', 'CONJ')],
#  [('and', 'CONJ'),
#   (('polyester', 'X'), ('polyester', 'NOUN')),
#   ('film', 'NOUN')],
#  [('are', 'VERB'),
#   (('non-biodegradable', 'X'), ('non-biodegradable', 'ADJ')),
#   ('.', '.')],
#  [("'s", 'PRT'),
#   (('seventh', 'X'), ('seventh', 'ADJ')),
#   ('principal', 'NOUN')],
#  [('The', 'DET'), (("'82", 'X'), ("'82", 'NUM')), ('Salon', 'NOUN')],
#  [('$', '.'), (('115', 'X'), ('115', 'NUM')), ('*U*', 'X')],
#  [('.', '.'), (('Researchers', 'X'), ('Researchers', 'NOUN')), ('at', 'ADP')],
#  [('*-1', 'X'), (('unwilling', 'X'), ('unwilling', 'ADJ')), ('*-2', 'X')],
#  [('and', 'CONJ'), (('manpower', 'X'), ('manpower', 'NOUN')), ('to', 'PRT')],
#  [('*', 'X'), (('removing', 'X'), ('removing', 'VERB')), ('hazards', 'NOUN')],
#  [('*', 'X'),
#   (('safeguarding', 'X'), ('safeguarding', 'VERB')),
#   ('safety', 'NOUN')],
#  [('Linda', 'NOUN'), (('Anku', 'X'), ('Anku', 'NOUN')), (',', '.')],
#  [('.', '.'),
#   (('Ketchum', 'X'), ('Ketchum', 'NOUN')),
#   ('Communications', 'NOUN')],
#  [('acquired', 'VERB'), (('Braun', 'X'), ('Braun', 'NOUN')), ('&', 'CONJ')],
#  [('Angeles', 'NOUN'),
#   (('investor-relations', 'X'), ('investor-relations', 'NOUN')),
#   ('and', 'CONJ')],
#  [('and', 'CONJ'),
#   (('marketing-communications', 'X'), ('marketing-communications', 'NOUN')),
#   ('firm', 'NOUN')],
#  [('``', '.'), (('headed', 'X'), ('headed', 'VERB')), ('for', 'ADP')],
#  [("n't", 'ADV'), (('curbed', 'X'), ('curbed', 'VERB')), ('*-1', 'X')],
#  [('*-1', 'X'),
#   (('leveraging', 'X'), ('leveraging', 'VERB')),
#   ('performance', 'NOUN')],
#  [('*-1', 'X'), (('owning', 'X'), ('owning', 'VERB')), ('more', 'ADJ')],
#  [('had', 'VERB'), (('flirted', 'X'), ('flirted', 'VERB')), ('with', 'ADP')],
#  [("'s", 'PRT'),
#   (('father-in-law', 'X'), ('father-in-law', 'NOUN')),
#   (',', '.')],
#  [(',', '.'), (('Gardner', 'X'), ('Gardner', 'NOUN')), ('G.', 'NOUN')],
#  [('G.', 'NOUN'), (('Hubbard', 'X'), ('Hubbard', 'NOUN')), (',', '.')],
#  [(',', '.'), (('wealthy', 'X'), ('wealthy', 'ADJ')), ('and', 'CONJ')],
#  [('and', 'CONJ'),
#   (('well-connected', 'X'), ('well-connected', 'ADJ')),
#   (',', '.')],
#  [('to', 'PRT'), (('Moon', 'X'), ('Moon', 'NOUN')), ('Landrieu', 'NOUN')],
#  [('Moon', 'NOUN'), (('Landrieu', 'X'), ('Landrieu', 'NOUN')), (',', '.')],
#  [("'s", 'PRT'), (('cavernous', 'X'), ('cavernous', 'ADJ')), (',', '.')],
#  [(',', '.'),
#   (('money-losing', 'X'), ('money-losing', 'ADJ')),
#   ('Superdome', 'NOUN')],
#  [('little', 'ADJ'), (('relevance', 'X'), ('relevance', 'NOUN')), ('.', '.')],
#  [('at', 'ADP'), (('143.93', 'X'), ('143.93', 'NUM')), ('yen', 'NOUN')],
#  [('of', 'ADP'), (('143.08', 'X'), ('143.08', 'NUM')), ('yen', 'NOUN')],
#  [('expensive', 'ADJ'),
#   (('cleanup', 'X'), ('cleanup', 'NOUN')),
#   ('equipment', 'NOUN')],
#  [('or', 'CONJ'),
#   (('burn', 'X'), ('burn', 'VERB')),
#   ('cleaner-burning', 'ADJ')],
#  [('burn', 'VERB'),
#   (('cleaner-burning', 'X'), ('cleaner-burning', 'ADJ')),
#   ('fuels', 'NOUN')],
#  [('cleaner-burning', 'ADJ'), (('fuels', 'X'), ('fuels', 'NOUN')), ('.', '.')],
#  [('of', 'ADP'), (('858,000', 'X'), ('858,000', 'NUM')), ('shares', 'NOUN')],
#  [('market', 'NOUN'),
#   (('overvalued', 'X'), ('overvalued', 'VERB')),
#   ('and', 'CONJ')],
#  [('.', '.'), (('Paris', 'X'), ('Paris', 'NOUN')), (',', '.')],
#  [(',', '.'), (('Brussels', 'X'), ('Brussels', 'NOUN')), (',', '.')],
#  [('and', 'CONJ'), (('Milan', 'X'), ('Milan', 'NOUN')), ('were', 'VERB')],
#  [('the', 'DET'), (('discretion', 'X'), ('discretion', 'NOUN')), ('0', 'X')],
#  [('to', 'PRT'), (('select', 'X'), ('select', 'VERB')), ('the', 'DET')],
#  [('$', '.'), (('306', 'X'), ('306', 'NUM')), ('million', 'NUM')],
#  [('an', 'DET'),
#   (('unrestricted', 'X'), ('unrestricted', 'ADJ')),
#   ('six-month', 'ADJ')],
#  [('also', 'ADV'), (('tempted', 'X'), ('tempted', 'VERB')), ('some', 'DET')],
#  [('its', 'PRON'), (('glory', 'X'), ('glory', 'NOUN')), ('*PPA*-1', 'X')],
#  [('had', 'VERB'), (('faded', 'X'), ('faded', 'VERB')), ('like', 'ADP')],
#  [('the', 'DET'), (('yellow', 'X'), ('yellow', 'ADJ')), ('bricks', 'NOUN')],
#  [('yellow', 'ADJ'), (('bricks', 'X'), ('bricks', 'NOUN')), ('of', 'ADP')],
#  [('broad', 'ADJ'), (('facade', 'X'), ('facade', 'NOUN')), ('.', '.')],
#  [('$', '.'), (('550,000', 'X'), ('550,000', 'NUM')), ('*U*', 'X')],
#  [('.', '.'), (('Four', 'X'), ('Four', 'NUM')), ('of', 'ADP')],
#  [('recently', 'ADV'),
#   (('diagnosed', 'X'), ('diagnosed', 'VERB')),
#   ('cancer', 'NOUN')],
#  [('a', 'DET'), (('27-year', 'X'), ('27-year', 'ADJ')), ('Reuters', 'NOUN')],
#  [('the', 'DET'),
#   (('information-services', 'X'), ('information-services', 'NOUN')),
#   ('company', 'NOUN')],
#  [('By', 'ADP'), (('1997', 'X'), ('1997', 'NUM')), (',', '.')],
#  [('of', 'ADP'),
#   (('cancer-causing', 'X'), ('cancer-causing', 'ADJ')),
#   ('asbestos', 'NOUN')],
#  [('be', 'VERB'), (('outlawed', 'X'), ('outlawed', 'VERB')), ('*-6', 'X')],
#  [('departure', 'NOUN'),
#   (('stemmed', 'X'), ('stemmed', 'VERB')),
#   ('from', 'ADP')],
#  [('board', 'NOUN'),
#   (('directorship', 'X'), ('directorship', 'NOUN')),
#   ('at', 'ADP')],
#  [('Israel', 'NOUN'), (('Silverman', 'X'), ('Silverman', 'NOUN')), (',', '.')],
#  [('an', 'DET'),
#   (('insurance-company', 'X'), ('insurance-company', 'NOUN')),
#   ('lawyer', 'NOUN')],
#  [('in', 'ADP'), (('jeopardy', 'X'), ('jeopardy', 'NOUN')), ('.', '.')],
#  [("''", '.'), (('NEW', 'X'), ('NEW', 'NOUN')), ('ACCOUNT', 'NOUN')],
#  [('NEW', 'NOUN'), (('ACCOUNT', 'X'), ('ACCOUNT', 'NOUN')), (':', '.')],
#  [('$', '.'), (('14.75', 'X'), ('14.75', 'NUM')), ('*U*', 'X')],
#  [('Lord', 'NOUN'), (('Chilver', 'X'), ('Chilver', 'NOUN')), (',', '.')],
#  [(',', '.'),
#   (('63-year-old', 'X'), ('63-year-old', 'ADJ')),
#   ('chairman', 'NOUN')],
#  [('China', 'NOUN'), (('Clays', 'X'), ('Clays', 'NOUN')), ('PLC', 'NOUN')],
#  [('.', '.'),
#   (('CoreStates', 'X'), ('CoreStates', 'NOUN')),
#   ('Financial', 'NOUN')],
#  [('named', 'VERB'), (('Earle', 'X'), ('Earle', 'NOUN')), ('Palmer', 'NOUN')],
#  [('Earle', 'NOUN'), (('Palmer', 'X'), ('Palmer', 'NOUN')), ('Brown', 'NOUN')],
#  [('&', 'CONJ'), (('Spiro', 'X'), ('Spiro', 'NOUN')), (',', '.')],
#  [('of', 'ADP'), (('escape', 'X'), ('escape', 'NOUN')), ('*ICH*-2', 'X')],
#  [('or', 'CONJ'), (('insanity', 'X'), ('insanity', 'NOUN')), ('?', '.')],
#  [('the', 'DET'), (('heirs', 'X'), ('heirs', 'NOUN')), ('of', 'ADP')],
#  [('.', '.'), (('Nylev', 'X'), ('Nylev', 'NOUN')), ('Municipal', 'NOUN')],
#  [('from', 'ADP'),
#   (('malnutrition', 'X'), ('malnutrition', 'NOUN')),
#   (',', '.')],
#  [(',', '.'), (('chest', 'X'), ('chest', 'NOUN')), ('diseases', 'NOUN')],
#  [(',', '.'),
#   (('cardiovascular', 'X'), ('cardiovascular', 'ADJ')),
#   ('disorders', 'NOUN')],
#  [(',', '.'),
#   (('infectious', 'X'), ('infectious', 'ADJ')),
#   ('diseases', 'NOUN')],
#  [('the', 'DET'),
#   (('aftereffects', 'X'), ('aftereffects', 'NOUN')),
#   ('of', 'ADP')],
#  [('of', 'ADP'), (('assaults', 'X'), ('assaults', 'NOUN')), ('and', 'CONJ')],
#  [('a', 'DET'), (('grandstander', 'X'), ('grandstander', 'NOUN')), ('.', '.')],
#  [('U.K.', 'NOUN'), (('luxury', 'X'), ('luxury', 'NOUN')), ('auto', 'NOUN')],
#  [('at', 'ADP'), (('879', 'X'), ('879', 'NUM')), ('pence', 'NOUN')],
#  [('$', '.'), (('13.90', 'X'), ('13.90', 'NUM')), ('*U*', 'X')],
#  [('and', 'CONJ'), (('shopped', 'X'), ('shopped', 'VERB')), ('*-3', 'X')],
#  [('consumers', 'NOUN'),
#   (('espouse', 'X'), ('espouse', 'VERB')),
#   ('what', 'PRON')],
#  [('of', 'ADP'),
#   (('deteriorating', 'X'), ('deteriorating', 'VERB')),
#   ('hearing', 'NOUN')],
#  [('Donald', 'NOUN'), (('Anderson', 'X'), ('Anderson', 'NOUN')), (',', '.')],
#  [('a', 'DET'),
#   (('59-year-old', 'X'), ('59-year-old', 'ADJ')),
#   ('Los', 'NOUN')],
#  [('``', '.'),
#   (('fluctuations', 'X'), ('fluctuations', 'NOUN')),
#   ('and', 'CONJ')],
#  [('the', 'DET'),
#   (('heebie-jeebies', 'X'), ('heebie-jeebies', 'NOUN')),
#   (',', '.')],
#  [('*', 'X'),
#   (('outlawing', 'X'), ('outlawing', 'VERB')),
#   ('program', 'NOUN')],
#  [('to', 'PRT'), (('display', 'X'), ('display', 'VERB')), ('the', 'DET')],
#  [('overhead', 'ADJ'),
#   (('projector', 'X'), ('projector', 'NOUN')),
#   ('and', 'CONJ')],
#  [('and', 'CONJ'),
#   (('underline', 'X'), ('underline', 'VERB')),
#   ('the', 'DET')],
#  [(',', '.'),
#   (('Old-House', 'X'), ('Old-House', 'NOUN')),
#   ('Journal', 'NOUN')],
#  [('all', 'DET'), (('126,000', 'X'), ('126,000', 'NUM')), ('copies', 'NOUN')],
#  [('two', 'NUM'),
#   (('round-trip', 'X'), ('round-trip', 'ADJ')),
#   ('tickets', 'NOUN')],
#  [('on', 'ADP'), (('Trans', 'X'), ('Trans', 'NOUN')), ('World', 'NOUN')],
#  [('Riviera', 'NOUN'), (('luxury', 'X'), ('luxury', 'NOUN')), ('car', 'NOUN')],
#  [('prices', 'NOUN'), (('soaring', 'X'), ('soaring', 'VERB')), (',', '.')],
#  [('the', 'DET'),
#   (('reclaimed', 'X'), ('reclaimed', 'VERB')),
#   ('commodities', 'NOUN')],
#  [("'s", 'PRT'), (('240-page', 'X'), ('240-page', 'ADJ')), ('report', 'NOUN')],
#  [('the', 'DET'),
#   (('Iran-Contra', 'X'), ('Iran-Contra', 'NOUN')),
#   ('Report', 'NOUN')],
#  [('$', '.'), (('221.4', 'X'), ('221.4', 'NUM')), ('million', 'NUM')],
#  [('.', '.'), (('Next', 'X'), ('Next', 'ADJ')), ('week', 'NOUN')],
#  [('the', 'DET'),
#   (('Philippine', 'X'), ('Philippine', 'NOUN')),
#   ('Fund', 'NOUN')],
#  [('by', 'ADP'),
#   (('Philippine', 'X'), ('Philippine', 'ADJ')),
#   ('President', 'NOUN')],
#  [('President', 'NOUN'),
#   (('Corazon', 'X'), ('Corazon', 'NOUN')),
#   ('Aquino', 'NOUN')],
#  [('Corazon', 'NOUN'), (('Aquino', 'X'), ('Aquino', 'NOUN')), ('--', '.')],
#  [('until', 'ADP'), (('midyear', 'X'), ('midyear', 'NOUN')), ('.', '.')],
#  [("''", '.'), (('Spending', 'X'), ('Spending', 'NOUN')), ('on', 'ADP')],
#  [(',', '.'),
#   (('nonresidential', 'X'), ('nonresidential', 'ADJ')),
#   ('construction', 'NOUN')],
#  [('$', '.'), (('99.1', 'X'), ('99.1', 'NUM')), ('billion', 'NUM')],
#  [('market', 'NOUN'),
#   (('awaits', 'X'), ('awaits', 'VERB')),
#   ('tomorrow', 'NOUN')],
#  [('.', '.'),
#   (('Aerospace', 'X'), ('Aerospace', 'NOUN')),
#   ('earnings', 'NOUN')],
#  [('earnings', 'NOUN'), (('sagged', 'X'), ('sagged', 'VERB')), ('37', 'NUM')],
#  [('the', 'DET'), (('bombers', 'X'), ('bombers', 'NOUN')), ('rolled', 'VERB')],
#  [('to', 'PRT'), (('88.32', 'X'), ('88.32', 'NUM')), ('billion', 'NUM')],
#  [('$', '.'), (('618.1', 'X'), ('618.1', 'NUM')), ('million', 'NUM')],
#  [('from', 'ADP'), (('77.6', 'X'), ('77.6', 'NUM')), ('billion', 'NUM')],
#  [('$', '.'), (('12.52', 'X'), ('12.52', 'NUM')), ('billion', 'NUM')],
#  [('$', '.'), (('11.95', 'X'), ('11.95', 'NUM')), ('billion', 'NUM')],
#  [('the', 'DET'),
#   (('shipboard', 'X'), ('shipboard', 'NOUN')),
#   ('meetings', 'NOUN')],
#  [('off', 'ADP'), (('Malta', 'X'), ('Malta', 'NOUN')), ('.', '.')],
#  [('.', '.'), (('NCNB', 'X'), ('NCNB', 'NOUN')), ('Corp.', 'NOUN')],
#  [('Financial', 'NOUN'),
#   (('Connections', 'X'), ('Connections', 'NOUN')),
#   ('Program', 'NOUN')],
#  [('young', 'ADJ'), (('adults', 'X'), ('adults', 'NOUN')), ('just', 'ADV')],
#  [('so', 'ADV'),
#   (('broadly', 'X'), ('broadly', 'ADV')),
#   ('construed', 'VERB')],
#  [('broadly', 'ADV'), (('construed', 'X'), ('construed', 'VERB')), ('*', 'X')],
#  [('would', 'VERB'),
#   (('emasculate', 'X'), ('emasculate', 'VERB')),
#   ('the', 'DET')],
#  [('and', 'CONJ'), (('swallow', 'X'), ('swallow', 'VERB')), ('the', 'DET')]]

# %%
# counting similar predicted tag sets that belongs to unknown words with previous word and next word
incorrect_tagged_cases = [(tagged_seq[i-1][1],j[0][1],tagged_seq[i+1][1]) for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1] and j[0][1] == T[0]]
Counter(incorrect_tagged_cases).most_common(15)
# Out:
# [(('.', 'X', 'NOUN'), 21),
#  (('DET', 'X', 'NOUN'), 21),
#  (('NOUN', 'X', '.'), 14),
#  (('.', 'X', 'NUM'), 12),
#  (('.', 'X', 'X'), 12),
#  (('ADP', 'X', 'NOUN'), 10),
#  (('.', 'X', '.'), 9),
#  (('X', 'X', 'NOUN'), 9),
#  (('X', 'X', '.'), 8),
#  (('ADP', 'X', '.'), 8),
#  (('X', 'X', 'X'), 8),
#  (('DET', 'X', 'ADP'), 8),
#  (('NOUN', 'X', 'NOUN'), 7),
#  (('VERB', 'X', 'X'), 6),
#  (('ADJ', 'X', '.'), 6)]

# %%
# counting similar actual tag sets that belongs to unknown words with previous word and next word
incorrect_tagged_cases = [(test_run_base[i-1][1],test_run_base[i][1], test_run_base[i+1][1]) for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1] and j[0][1] == T[0]]
Counter(incorrect_tagged_cases).most_common(15)
# Out:
# [(('NOUN', 'NOUN', '.'), 20),
#  (('.', 'NOUN', 'NOUN'), 16),
#  (('NOUN', 'NOUN', 'NOUN'), 12),
#  (('.', 'NUM', 'NUM'), 12),
#  (('DET', 'ADJ', 'NOUN'), 10),
#  (('DET', 'NOUN', 'NOUN'), 10),
#  (('.', 'ADJ', 'NOUN'), 9),
#  (('.', 'NOUN', '.'), 8),
#  (('DET', 'NOUN', 'ADP'), 8),
#  (('ADJ', 'NOUN', '.'), 7),
#  (('ADJ', 'NOUN', 'ADP'), 6),
#  (('ADP', 'NOUN', '.'), 6),
#  (('X', 'VERB', 'NOUN'), 5),
#  (('VERB', 'VERB', 'X'), 5),
#  (('.', 'NUM', 'X'), 5)]

# %% [markdown]
# As we can see in the above two results of actual tag sets and predicted tag sets of unknown words that tag sets are following some pattern with previous and next tags.
#
# For example: actual tag sets ('.', 'NUM', 'NUM') and predicted tag set ('.', 'X', 'NUM'); if previous tag of unknown word is '.' and next tag of unknown word is 'NUM' then unknown word should be tagged as 'NUM', not as 'X'.

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# ### Solve the problem of unknown words

# %% [markdown]
# ### Technique I
# Previous and next tag based Technique

# %%
# Modifing Viterbi algorithm for tagging sequence of words of a sentence
def Viterbi_modify1(words, train_bag = train_tagged_words):
    state = []
    final_words = words.copy()
    T = list(set([pair[1] for pair in train_bag]))
    T.sort(reverse=True)
    for key, word in enumerate(words):
        p = [] 
        word_presence = 0
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
            # computing emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            word_presence += word_given_tag(words[key], tag)[0] 
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        # if word is unknown then word_presence will be 0
        if word_presence == 0:
            words[key] = "ABCD" # replacing unknown words with ABCD
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    t_w = list(zip(words, state))
    count_t_w = len(t_w)
    # loop for tagging unknown words
    for index in range(count_t_w):
        tag_max = ""
        if t_w[index][0]=='ABCD':
            if index == 0:
                t1 = '.' # for the first word, previous tag should be '.'
            else:
                t1 = t_w[index-1][1]
            if index == (count_t_w-1):
                t3 = '.' # for the last word, next tag should be '.'
            else:    
                t3 = t_w[index+1][1]
            tags = [pair[1] for pair in train_tagged_words]
            count_t3_t1 = 0
            # counting the combinations of previous and next tag of unknown word
            for i in range(len(tags)-2):
                if tags[i]==t1 and tags[i+2] == t3:
                    count_t3_t1 += 1
            prob = []
            # counting the combination of previous and next tag with all possible tags of unknown word
            for t2 in T:
                count_t3_t2_t1 = 0
                for i in range(len(tags)-2):
                    if tags[i]==t1 and tags[i+1] == t2 and tags[i+2] == t3:
                        count_t3_t2_t1 += 1
                prob.append(count_t3_t2_t1/count_t3_t1)
            probmax = max(prob)
            # getting state for which probability is maximum
            tag_max = T[prob.index(probmax)]
            state[index] = tag_max

    return list(zip(final_words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# evaluating the accuracy of the Viterbi algorithm on the test dataset

# getting list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# getting list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# tagging the test sentences
tagged_seq = Viterbi_modify1(test_tagged_words)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy_modfy1_viterbi = len(check)/len(tagged_seq)
accuracy_modfy1_viterbi
# Out:
# 0.9314575840913899

# %% [markdown]
# #### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
print("Tagging accuracy of vanilla Viterbi algorithm: {}%".format(int(round(accuracy_vnila_viterbi, 2)*100)))
print("Tagging accuracy of modified Viterbi algorithm: {}%".format(int(round(accuracy_modfy1_viterbi, 2)*100)))
# Out:
# Tagging accuracy of vanilla Viterbi algorithm: 91%
# Tagging accuracy of modified Viterbi algorithm: 93%

# %% [markdown]
# Tagging accuracy improved by 2% with modified Viterbi algorithm.

# %% [markdown]
# #### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Three sentences from sample test file which is incorrectly tagging by original POS tagger(Viterbi())
# and correctly tagging by modified POS tagger
sent1 = "Before entering politics, Donald Trump was a domineering businessman and a television personality."
sent2 = "Android is a mobile operating system developed by Google."
sent3 = "NASA invited social media users to experience the launch of ICESAT-2 Satellite."
print("1) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent1)))
print("1) Correctly tagged sentence:")
print(Viterbi_modify1(word_tokenize(sent1)))
print("\n")
print("2) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent2)))
print("2) Correctly tagged sentence:")
print(Viterbi_modify1(word_tokenize(sent2)))
print("\n")
print("3) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent3)))
print("3) Correctly tagged sentence:")
print(Viterbi_modify1(word_tokenize(sent3)))
# Out:
# 1) Incorrectly tagged sentence:
# [('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'X'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'X'), ('.', '.')]
# 1) Correctly tagged sentence:
# [('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'ADJ'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.')]
#
#
# 2) Incorrectly tagged sentence:
# [('Android', 'X'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'X'), ('.', '.')]
# 2) Correctly tagged sentence:
# [('Android', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.')]
#
#
# 3) Incorrectly tagged sentence:
# [('NASA', 'X'), ('invited', 'X'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'X'), ('Satellite', 'X'), ('.', '.')]
# 3) Correctly tagged sentence:
# [('NASA', 'VERB'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'X'), ('.', '.')]

# %% [markdown]
# As we can see that modified viterbi algorithm correctly tagged the words:
# - In the first sentence, algorithm changed ('personality', 'X') to ('personality', 'NOUN').
# - In the second sentence, algorithm changed ('Google', 'X') to ('Google', 'NOUN').
# - In the third sentence, algorithm changed ('NASA', 'X') to ('NASA', 'NOUN'), ('ICESAT-2', 'X') to ('ICESAT-2', 'NOUN'), ('Satellite', 'X') to ('Satellite', 'NOUN').

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# ### Technique II
# Morphology based Technique

# %%
# Modifing Viterbi algorithm 2 for tagging sequence of words of a sentence
def Viterbi_modify2(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    T.sort(reverse=True)
    for key, word in enumerate(words):
        p = [] 
        word_presence = 0
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
            # computing emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            word_presence += word_given_tag(words[key], tag)[0] 
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        # if word is unknown then word_presence will be 0
        if word_presence == 0:
            # regular expressions based condition for unknown word that has certain prefix or suffix
            if type(re.search(r'^(\d)+(.)?(\d)+$', words[key])) == re.Match: 
                state.append('NUM')
            elif type(re.search(r'^[a-z-]{2,}(ed|ing|ize)$', words[key])) == re.Match:
                state.append('VERB')
            elif type(re.search(r'^[a-z-]{1,}(est|ous|er|en|ful|ive|ent|ble)$', words[key])) == re.Match:
                state.append('ADJ')
            elif type(re.search(r'^(un)[a-z-]{1,}', words[key])) == re.Match:
                state.append('ADJ')
            elif type(re.search(r'[a-z-]{2,}ly$', words[key])) == re.Match:
                state.append('ADV')
            else:
                state.append('NOUN')
        else:
            pmax = max(p)
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# evaluating the accuracy of the Viterbi algorithm on the test dataset

# getting list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# getting list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# tagging the test sentences
tagged_seq = Viterbi_modify2(test_tagged_words)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy_modfy2_viterbi = len(check)/len(tagged_seq)
accuracy_modfy2_viterbi
# Out:
# 0.9496509414004655

# %% [markdown]
# #### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
print("Tagging accuracy of vanilla Viterbi algorithm: {}%".format(int(round(accuracy_vnila_viterbi, 2)*100))) 
print("Tagging accuracy of modified Viterbi algorithm: {}%".format(int(round(accuracy_modfy2_viterbi, 2)*100)))
# Out:
# Tagging accuracy of vanilla Viterbi algorithm: 91%
# Tagging accuracy of modified Viterbi algorithm: 95%

# %% [markdown]
# Tagging accuracy improved by 4% with modified Viterbi algorithm.

# %% [markdown]
# #### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Three sentences from sample test file which is incorrectly tagging by original POS tagger(Viterbi())
# and correctly tagging by modified POS tagger
sent1 = "Android is a mobile operating system developed by Google."
sent2 = "Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013."
sent3 = "This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe."
print("1) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent1)))
print("1) Correctly tagged sentence:")
print(Viterbi_modify2(word_tokenize(sent1)))
print("\n")
print("2) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent2)))
print("2) Correctly tagged sentence:")
print(Viterbi_modify2(word_tokenize(sent2)))
print("\n")
print("3) Incorrectly tagged sentence:")
print(Viterbi(word_tokenize(sent3)))
print("3) Correctly tagged sentence:")
print(Viterbi_modify2(word_tokenize(sent3)))
# Out:
# 1) Incorrectly tagged sentence:
# [('Android', 'X'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'X'), ('.', '.')]
# 1) Correctly tagged sentence:
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.')]
#
#
# 2) Incorrectly tagged sentence:
# [('Android', 'X'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'X'), ('worldwide', 'X'), ('on', 'ADP'), ('smartphones', 'X'), ('since', 'ADP'), ('2011', 'X'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'X'), ('.', '.')]
# 2) Correctly tagged sentence:
# [('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'NOUN'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.')]
#
#
# 3) Incorrectly tagged sentence:
# [('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'X'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.')]
# 3) Correctly tagged sentence:
# [('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.')]

# %% [markdown]
# As we can see that modified viterbi algorithm correctly tagged the words:
# - In the first sentence, algorithm changed ('Android', 'X') to ('Android', 'NOUN'), ('Google', 'X') to ('Google', 'NOUN').
# - In the second sentence, algorithm changed ('Android', 'X') to ('Android', 'NOUN'), ('OS', 'X') to ('OS', 'NOUN'), ('worldwide', 'X') to ('worldwide', 'NOUN'), ('smartphones', 'X') to ('smartphones', 'NOUN'), ('2011', 'X') to ('2011', 'NUM'), ('2013', 'X') to ('2013', 'NUM').
# - In the third sentence, algorithm changed (('Cup', 'X') to ('Cup', 'NOUN').
